# %% [markdown]
# ![image.png](attachment:50460336-cd21-43f9-b7b4-f0dbe10b3829.png)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\proko\\Desktop\\university\\iii\\matd\\leactures\\exercises\\2'

# %%
path = ''

# %% [markdown]
# # Naive (brute-force) pattern matching

# %% [markdown]
# https://www.geeksforgeeks.org/naive-algorithm-for-pattern-searching/

# %% [markdown]
# ### Solution

# %% [markdown]
# # Knuth-Morris-Pratt algorithm (KMP)

# %% [markdown]
# https://www.geeksforgeeks.org/kmp-algorithm-for-pattern-searching/

# %% [markdown]
# pattern = AABAACAABAA
#
# | i | LPS | Substring | Prefixy | Suffixy |
# |---|---|---|---|---|
# | 0  | 0  | A  | e  | e, A |
# | 1  |  1 | AA  | e, A  | e, A, AA  |
# |  2 |  0 | AAB  | e, A, AA  | e, B, AB, AAB  |
# |  2 |  1 | AABA  | e, A, AA, AAB  | e, B, AB, AAB, AABA  |
#
# - pokud jsme nasli velikost toho pak mam vzor v textu
